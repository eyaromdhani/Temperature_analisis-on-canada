# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
df = pd.read_csv("./us_data.csv")##reads the file into data frame and assigns it to the variable df
df ## displays the data frame
# Out:
#     PARAMETER  YEAR    LAT    LON   JAN   FEB   MAR   APR    MAY    JUN  \
# 0         T2M  1995  39.75 -72.25  7.33  4.62  7.08  8.85  12.86  17.84
# 1         T2M  1995  39.75 -72.75  6.56  3.77  6.64  8.51  12.70  17.88
# 2         T2M  1995  39.75 -73.25  5.73  2.81  6.09  8.35  12.70  18.13
# 3         T2M  1995  39.75 -73.75  4.76  1.80  5.60  8.40  13.12  18.68
# 4         T2M  1995  39.75 -74.25  3.37  0.25  5.54  9.05  14.34  19.93
# ..        ...   ...    ...    ...   ...   ...   ...   ...    ...    ...
# 975       T2M  2022  41.75 -73.25 -5.78 -2.39  2.26  7.23  14.99  19.06
# 976       T2M  2022  41.75 -73.75 -5.90 -2.51  2.40  7.37  15.29  19.24
# 977       T2M  2022  41.75 -74.25 -6.92 -3.54  1.59  6.45  14.65  18.29
# 978       T2M  2022  41.75 -74.75 -7.38 -4.03  1.19  5.92  14.36  17.84
# 979       T2M  2022  41.75 -75.25 -7.48 -4.17  1.14  5.71  14.32  17.69
#
#        JUL    AUG    SEP    OCT    NOV   DEC    ANN
# ...

# %%
df.head(10)
# Out:
#   PARAMETER  YEAR    LAT    LON   JAN   FEB   MAR   APR    MAY    JUN    JUL  \
# 0       T2M  1995  39.75 -72.25  7.33  4.62  7.08  8.85  12.86  17.84  22.34
# 1       T2M  1995  39.75 -72.75  6.56  3.77  6.64  8.51  12.70  17.88  22.42
# 2       T2M  1995  39.75 -73.25  5.73  2.81  6.09  8.35  12.70  18.13  22.73
# 3       T2M  1995  39.75 -73.75  4.76  1.80  5.60  8.40  13.12  18.68  23.38
# 4       T2M  1995  39.75 -74.25  3.37  0.25  5.54  9.05  14.34  19.93  24.44
# 5       T2M  1995  39.75 -74.75  2.38 -0.86  5.50  9.39  15.13  20.89  25.24
# 6       T2M  1995  39.75 -75.25  1.75 -1.48  5.42  9.44  15.46  21.45  25.58
# 7       T2M  1995  40.25 -72.25  5.97  3.03  5.60  7.69  11.86  17.09  21.73
# 8       T2M  1995  40.25 -72.75  5.25  2.20  5.32  7.69  12.02  17.56  22.14
# 9       T2M  1995  40.25 -73.25  4.47  1.31  5.00  7.84  12.47  18.26  22.83
#
#      AUG    SEP    OCT    NOV   DEC    ANN
# 0  22.79  20.21  17.97  11.54  6.02  13.35
# ...

# %%
df.shape ## gives you the total number of rows / columns
# Out:
# (980, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PARAMETER  980 non-null    object
#  1   YEAR       980 non-null    int64
#  2   LAT        980 non-null    float64
#  3   LON        980 non-null    float64
#  4   JAN        980 non-null    float64
#  5   FEB        980 non-null    float64
#  6   MAR        980 non-null    float64
#  7   APR        980 non-null    float64
#  8   MAY        980 non-null    float64
#  9   JUN        980 non-null    float64
#  10  JUL        980 non-null    float64
#  11  AUG        980 non-null    float64
#  12  SEP        980 non-null    float64
#  13  OCT        980 non-null    float64
#  14  NOV        980 non-null    float64
#  15  DEC        980 non-null    float64
#  16  ANN        980 non-null    float64
# dtypes: float64(15), int64(1), object(1)
# memory usage: 130.3+ KB

# %%
df.describe()
# Out:
#               YEAR         LAT         LON         JAN         FEB  \
# count   980.000000  980.000000  980.000000  980.000000  980.000000
# mean   2008.500000   40.750000  -73.750000   -0.612786   -0.035337
# std       8.081872    0.707468    1.000511    3.878919    3.482614
# min    1995.000000   39.750000  -75.250000   -9.740000  -12.300000
# 25%    2001.750000   40.250000  -74.750000   -3.475000   -2.342500
# 50%    2008.500000   40.750000  -73.750000   -0.780000    0.090000
# 75%    2015.250000   41.250000  -72.750000    2.332500    2.542500
# max    2022.000000   41.750000  -72.250000    8.370000    7.640000
#
#               MAR        APR         MAY         JUN         JUL         AUG  \
# count  980.000000  980.00000  980.000000  980.000000  980.000000  980.000000
# mean     3.311908    8.48752   14.052673   19.441388   23.012020   22.840847
# std      2.444020    1.51795    1.600957    1.280055    1.518668    1.453331
# ...

# %%
df.describe(include='all')
# Out:
#        PARAMETER         YEAR         LAT         LON         JAN         FEB  \
# count        980   980.000000  980.000000  980.000000  980.000000  980.000000
# unique         1          NaN         NaN         NaN         NaN         NaN
# top          T2M          NaN         NaN         NaN         NaN         NaN
# freq         980          NaN         NaN         NaN         NaN         NaN
# mean         NaN  2008.500000   40.750000  -73.750000   -0.612786   -0.035337
# std          NaN     8.081872    0.707468    1.000511    3.878919    3.482614
# min          NaN  1995.000000   39.750000  -75.250000   -9.740000  -12.300000
# 25%          NaN  2001.750000   40.250000  -74.750000   -3.475000   -2.342500
# 50%          NaN  2008.500000   40.750000  -73.750000   -0.780000    0.090000
# 75%          NaN  2015.250000   41.250000  -72.750000    2.332500    2.542500
# max          NaN  2022.000000   41.750000  -72.250000    8.370000    7.640000
#
# ...

# %%
# Drop duplicates based on the 'year' column, keeping the first occurrence
df_unique_years = df.drop_duplicates(subset=['YEAR'], keep='first')

df_unique_years
# Out:
#     PARAMETER  YEAR    LAT    LON   JAN   FEB   MAR    APR    MAY    JUN  \
# 0         T2M  1995  39.75 -72.25  7.33  4.62  7.08   8.85  12.86  17.84
# 35        T2M  1996  39.75 -72.25  5.13  3.78  4.39   7.91  12.07  18.68
# 70        T2M  1997  39.75 -72.25  4.60  5.86  6.29   7.99  11.94  16.34
# 105       T2M  1998  39.75 -72.25  7.18  5.83  5.69   8.30  12.19  17.60
# 140       T2M  1999  39.75 -72.25  6.33  5.66  6.04   8.74  13.01  18.95
# 175       T2M  2000  39.75 -72.25  5.42  6.18  7.84   9.39  14.01  17.73
# 210       T2M  2001  39.75 -72.25  4.79  4.72  5.27   8.08  13.18  19.46
# 245       T2M  2002  39.75 -72.25  8.37  6.83  7.62   9.89  12.87  17.87
# 280       T2M  2003  39.75 -72.25  3.30  3.42  5.28   7.25  11.13  16.22
# 315       T2M  2004  39.75 -72.25  1.96  4.08  5.06   8.43  13.69  18.04
# 350       T2M  2005  39.75 -72.25  4.75  4.25  4.56   8.17  10.76  17.91
# 385       T2M  2006  39.75 -72.25  7.86  4.96  5.70   9.86  14.06  18.30
# ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['YEAR'], df['ANN'])
plt.title('Temperature in New York')
plt.xlabel('Year')
plt.ylabel('Temperature')
plt.grid(True)
plt.show()

# %%
# Create the histogram
plt.hist(df['ANN'], bins=20, color='cyan', edgecolor='black')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.title('Temperature Distribution')
plt.grid(True)
plt.show()

# %%
# Load the shapefile using geopandas
gdf = gpd.read_file("gadm41_USA_1.shp")
fig, ax = plt.subplots(figsize=(40, 40))
gdf.plot(ax=ax, color='lightgray', edgecolor='black')
plt.show()

# %%
# Load the shapefile using geopandas
gdf = gpd.read_file("gadm41_USA_1.shp")
fig, ax = plt.subplots(figsize=(40, 40))
gdf.plot(ax=ax, color='lightgray', edgecolor='black')
# Remove axes
ax.set_axis_off()
plt.title('USA Map (Enlarged)', fontsize=20)#adjusted fontsize
plt.show()
